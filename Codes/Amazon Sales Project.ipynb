# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np
data = pd.read_csv("Amazon1.csv")
print(data)
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0      ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1      ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2      ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
# 3      ORD0000004  2023-07-18  CUST030059   Vihaan Reddy    P00041
# 4      ORD0000005  2023-02-04  CUST048677  Aditya Kapoor    P00029
# ...           ...         ...         ...            ...       ...
# 99995  ORD0099996  2023-03-07  CUST001356    Karan Joshi    P00047
# 99996  ORD0099997  2021-11-24  CUST031254  Sunita Kapoor    P00046
# 99997  ORD0099998  2023-04-29  CUST012579     Aman Gupta    P00030
# 99998  ORD0099999  2021-11-01  CUST026243   Simran Gupta    P00046
# 99999  ORD0100000  2021-12-04  CUST029492   Sunita Reddy    P00019
#
#                ProductName           Category       Brand  Quantity  \
# 0               Drone Mini              Books   BrightLux         3
# ...

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0      ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1      ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2      ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
# 3      ORD0000004  2023-07-18  CUST030059   Vihaan Reddy    P00041
# 4      ORD0000005  2023-02-04  CUST048677  Aditya Kapoor    P00029
# ...           ...         ...         ...            ...       ...
# 99995  ORD0099996  2023-03-07  CUST001356    Karan Joshi    P00047
# 99996  ORD0099997  2021-11-24  CUST031254  Sunita Kapoor    P00046
# 99997  ORD0099998  2023-04-29  CUST012579     Aman Gupta    P00030
# 99998  ORD0099999  2021-11-01  CUST026243   Simran Gupta    P00046
# 99999  ORD0100000  2021-12-04  CUST029492   Sunita Reddy    P00019
#
#                ProductName           Category       Brand  Quantity  \
# 0               Drone Mini              Books   BrightLux         3
# ...

# %%
df.head(10)
# Out:
#       OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0  ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1  ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2  ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
# 3  ORD0000004  2023-07-18  CUST030059   Vihaan Reddy    P00041
# 4  ORD0000005  2023-02-04  CUST048677  Aditya Kapoor    P00029
# 5  ORD0000006  2022-12-31  CUST042705   Karan Sharma    P00023
# 6  ORD0000007  2024-09-20  CUST037667    Aarav Verma    P00030
# 7  ORD0000008  2022-11-10  CUST031165    Rohit Kumar    P00028
# 8  ORD0000009  2024-06-26  CUST026965    Aman Kapoor    P00031
# 9  ORD0000010  2020-05-01  CUST029472    Aarav Reddy    P00001
#
#            ProductName           Category       Brand  Quantity  UnitPrice  \
# 0           Drone Mini              Books   BrightLux         3     106.59
# 1           Microphone     Home & Kitchen  UrbanStyle         1     251.37
# ...

# %%
df.tail(10)
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 99990  ORD0099991  2024-05-29  CUST019886   Sneha Kapoor    P00001
# 99991  ORD0099992  2021-05-08  CUST005627    Kabir Reddy    P00009
# 99992  ORD0099993  2021-07-17  CUST030861   Simran Verma    P00017
# 99993  ORD0099994  2023-05-04  CUST045239   Mohit Sharma    P00029
# 99994  ORD0099995  2022-01-09  CUST028035   Kabir Kapoor    P00011
# 99995  ORD0099996  2023-03-07  CUST001356    Karan Joshi    P00047
# 99996  ORD0099997  2021-11-24  CUST031254  Sunita Kapoor    P00046
# 99997  ORD0099998  2023-04-29  CUST012579     Aman Gupta    P00030
# 99998  ORD0099999  2021-11-01  CUST026243   Simran Gupta    P00046
# 99999  ORD0100000  2021-12-04  CUST029492   Sunita Reddy    P00019
#
#              ProductName           Category      Brand  Quantity  UnitPrice  \
# 99990   Wireless Earbuds        Electronics   KiddoFun         1     150.64
# ...

# %%
df.shape
# Out:
# (100000, 20)

# %%
df.columns
# Out:
# Index(['OrderID', 'OrderDate', 'CustomerID', 'CustomerName', 'ProductID',
#        'ProductName', 'Category', 'Brand', 'Quantity', 'UnitPrice', 'Discount',
#        'Tax', 'ShippingCost', 'TotalAmount', 'PaymentMethod', 'OrderStatus',
#        'City', 'State', 'Country', 'SellerID'],
#       dtype='str')

# %%
df.dtypes
# Out:
# OrderID              str
# OrderDate            str
# CustomerID           str
# CustomerName         str
# ProductID            str
# ProductName          str
# Category             str
# Brand                str
# Quantity           int64
# UnitPrice        float64
# Discount         float64
# Tax              float64
# ShippingCost     float64
# TotalAmount      float64
# PaymentMethod        str
# OrderStatus          str
# City                 str
# State                str
# Country              str
# SellerID             str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   OrderID        100000 non-null  str
#  1   OrderDate      100000 non-null  str
#  2   CustomerID     100000 non-null  str
#  3   CustomerName   100000 non-null  str
#  4   ProductID      100000 non-null  str
#  5   ProductName    100000 non-null  str
#  6   Category       100000 non-null  str
#  7   Brand          100000 non-null  str
#  8   Quantity       100000 non-null  int64
#  9   UnitPrice      100000 non-null  float64
#  10  Discount       100000 non-null  float64
#  11  Tax            100000 non-null  float64
#  12  ShippingCost   100000 non-null  float64
#  13  TotalAmount    100000 non-null  float64
#  14  PaymentMethod  100000 non-null  str
#  15  OrderStatus    100000 non-null  str
#  16  City           100000 non-null  str
#  17  State          100000 non-null  str
# ...

# %%
df.describe()
# Out:
#             Quantity      UnitPrice       Discount            Tax  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        3.001400     302.905748       0.074226      68.468902
# std         1.413548     171.840797       0.082583      74.131180
# min         1.000000       5.000000       0.000000       0.000000
# 25%         2.000000     154.190000       0.000000      15.920000
# 50%         3.000000     303.070000       0.050000      45.250000
# 75%         4.000000     451.500000       0.100000      96.060000
# max         5.000000     599.990000       0.300000     538.460000
#
#         ShippingCost    TotalAmount
# count  100000.000000  100000.000000
# mean        7.406660     918.256479
# std         4.324057     724.508332
# min         0.000000       4.270000
# 25%         3.680000     340.890000
# 50%         7.300000     714.315000
# 75%        11.150000    1349.765000
# max        15.000000    3534.980000

# %%
df.isnull().sum()
# Out:
# OrderID          0
# OrderDate        0
# CustomerID       0
# CustomerName     0
# ProductID        0
# ProductName      0
# Category         0
# Brand            0
# Quantity         0
# UnitPrice        0
# Discount         0
# Tax              0
# ShippingCost     0
# TotalAmount      0
# PaymentMethod    0
# OrderStatus      0
# City             0
# State            0
# Country          0
# SellerID         0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Length: 100000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["OrderDate"] = pd.to_datetime(df["OrderDate"])

# %%
df.dtypes
# Out:
# OrderID                     str
# OrderDate        datetime64[us]
# CustomerID                  str
# CustomerName                str
# ProductID                   str
# ProductName                 str
# Category                    str
# Brand                       str
# Quantity                  int64
# UnitPrice               float64
# Discount                float64
# Tax                     float64
# ShippingCost            float64
# TotalAmount             float64
# PaymentMethod               str
# OrderStatus                 str
# City                        str
# State                       str
# Country                     str
# SellerID                    str
# dtype: object

# %%
df["OrderMonth"] = df["OrderDate"].dt.month

# %%
df.dtypes
# Out:
# OrderID                     str
# OrderDate        datetime64[us]
# CustomerID                  str
# CustomerName                str
# ProductID                   str
# ProductName                 str
# Category                    str
# Brand                       str
# Quantity                  int64
# UnitPrice               float64
# Discount                float64
# Tax                     float64
# ShippingCost            float64
# TotalAmount             float64
# PaymentMethod               str
# OrderStatus                 str
# City                        str
# State                       str
# Country                     str
# SellerID                    str
# OrderMonth                int32
# dtype: object

# %%
df[["OrderDate","OrderMonth"]].head()
# Out:
#    OrderDate  OrderMonth
# 0 2023-01-31           1
# 1 2023-12-30          12
# 2 2022-05-10           5
# 3 2023-07-18           7
# 4 2023-02-04           2

# %%
df["OrderYear"] = df["OrderDate"].dt.year

# %%
df[["OrderDate","OrderYear"]].head()
# Out:
#    OrderDate  OrderYear
# 0 2023-01-31       2023
# 1 2023-12-30       2023
# 2 2022-05-10       2022
# 3 2023-07-18       2023
# 4 2023-02-04       2023

# %%
df["MonthName"] = df["OrderDate"].dt.month_name()

# %%
df[["OrderDate","MonthName"]].head()
# Out:
#    OrderDate MonthName
# 0 2023-01-31   January
# 1 2023-12-30  December
# 2 2022-05-10       May
# 3 2023-07-18      July
# 4 2023-02-04  February

# %%
df["DayName"] = df["OrderDate"].dt.day_name()

# %%
df[["OrderDate","DayName"]].head()
# Out:
#    OrderDate   DayName
# 0 2023-01-31   Tuesday
# 1 2023-12-30  Saturday
# 2 2022-05-10   Tuesday
# 3 2023-07-18   Tuesday
# 4 2023-02-04  Saturday

# %%
df[["OrderDate","DayName","MonthName","OrderYear"]].head(10)
# Out:
#    OrderDate    DayName  MonthName  OrderYear
# 0 2023-01-31    Tuesday    January       2023
# 1 2023-12-30   Saturday   December       2023
# 2 2022-05-10    Tuesday        May       2022
# 3 2023-07-18    Tuesday       July       2023
# 4 2023-02-04   Saturday   February       2023
# 5 2022-12-31   Saturday   December       2022
# 6 2024-09-20     Friday  September       2024
# 7 2022-11-10   Thursday   November       2022
# 8 2024-06-26  Wednesday       June       2024
# 9 2020-05-01     Friday        May       2020

# %%
df["Quarter"] = df["OrderDate"].dt.quarter

# %%
df[["OrderDate","Quarter"]].head()
# Out:
#    OrderDate  Quarter
# 0 2023-01-31        1
# 1 2023-12-30        4
# 2 2022-05-10        2
# 3 2023-07-18        3
# 4 2023-02-04        1

# %%
df[["OrderDate","DayName","MonthName","OrderYear","Quarter"]].head(10)
# Out:
#    OrderDate    DayName  MonthName  OrderYear  Quarter
# 0 2023-01-31    Tuesday    January       2023        1
# 1 2023-12-30   Saturday   December       2023        4
# 2 2022-05-10    Tuesday        May       2022        2
# 3 2023-07-18    Tuesday       July       2023        3
# 4 2023-02-04   Saturday   February       2023        1
# 5 2022-12-31   Saturday   December       2022        4
# 6 2024-09-20     Friday  September       2024        3
# 7 2022-11-10   Thursday   November       2022        4
# 8 2024-06-26  Wednesday       June       2024        2
# 9 2020-05-01     Friday        May       2020        2

# %%
df["PriceCategory"] = pd.cut(df["UnitPrice"], bins = [0,200,400,600], labels = ["Low", "Medium", "High"])

# %%
df[["UnitPrice","PriceCategory"]].head()
# Out:
#    UnitPrice PriceCategory
# 0     106.59           Low
# 1     251.37        Medium
# 2      35.03           Low
# 3      33.58           Low
# 4     515.64          High

# %%
df["DiscountPercent"] = df["Discount"] * 100

# %%
df[["Discount","DiscountPercent"]].head()
# Out:
#    Discount  DiscountPercent
# 0      0.00              0.0
# 1      0.05              5.0
# 2      0.10             10.0
# 3      0.15             15.0
# 4      0.25             25.0

# %%
df[["OrderDate", "OrderMonth", "OrderYear", "MonthName", "DayName", "Quarter", "PriceCategory", "DiscountPercent"]].head(10)
# Out:
#    OrderDate  OrderMonth  OrderYear  MonthName    DayName  Quarter  \
# 0 2023-01-31           1       2023    January    Tuesday        1
# 1 2023-12-30          12       2023   December   Saturday        4
# 2 2022-05-10           5       2022        May    Tuesday        2
# 3 2023-07-18           7       2023       July    Tuesday        3
# 4 2023-02-04           2       2023   February   Saturday        1
# 5 2022-12-31          12       2022   December   Saturday        4
# 6 2024-09-20           9       2024  September     Friday        3
# 7 2022-11-10          11       2022   November   Thursday        4
# 8 2024-06-26           6       2024       June  Wednesday        2
# 9 2020-05-01           5       2020        May     Friday        2
#
#   PriceCategory  DiscountPercent
# 0           Low              0.0
# 1        Medium              5.0
# 2           Low             10.0
# 3           Low             15.0
# 4          High             25.0
# ...

# %%
df["Category"] = df["Category"].str.title()

# %%
df["Category"].head(10)
# Out:
# 0                Books
# 1       Home & Kitchen
# 2             Clothing
# 3       Home & Kitchen
# 4             Clothing
# 5                Books
# 6             Clothing
# 7         Toys & Games
# 8    Sports & Outdoors
# 9             Clothing
# Name: Category, dtype: str

# %%
df["Brand"] = df["Brand"].str.upper()
df["Brand"].head(10)
# Out:
# 0     BRIGHTLUX
# 1    URBANSTYLE
# 2    URBANSTYLE
# 3        ZENITH
# 4      KIDDOFUN
# 5      READMORE
# 6    URBANSTYLE
# 7      KIDDOFUN
# 8          APEX
# 9          APEX
# Name: Brand, dtype: str

# %%
df = df.sort_values(by = "TotalAmount", ascending=False)
df[["ProductName","TotalAmount"]].head(10)
# Out:
#              ProductName  TotalAmount
# 48442      Puzzle 1000pc      3534.98
# 81886   Wireless Charger      3521.85
# 4196             T-Shirt      3514.24
# 1929       Running Shoes      3513.65
# 58204       Kids Toy Car      3513.05
# 46764     Desk Organizer      3511.95
# 40146  Bluetooth Speaker      3510.23
# 20578        Instant Pot      3509.30
# 95429       Gaming Mouse      3499.15
# 51547      Action Camera      3498.13

# %%
high_sales = df[df["TotalAmount"] > 100]
high_sales.head(10)
# Out:
#           OrderID  OrderDate  CustomerID  CustomerName ProductID  \
# 48442  ORD0048443 2020-01-12  CUST010794  Anjali Patel    P00033
# 81886  ORD0081887 2020-09-26  CUST031626  Vivaan Joshi    P00048
# 4196   ORD0004197 2021-02-22  CUST022868   Kabir Gupta    P00029
# 1929   ORD0001930 2023-08-18  CUST031209   Pooja Patel    P00025
# 58204  ORD0058205 2021-10-19  CUST033287   Priya Gupta    P00031
# 46764  ORD0046765 2024-04-13  CUST044400  Priya Kapoor    P00034
# 40146  ORD0040147 2024-10-07  CUST001991   Pooja Mehta    P00002
# 20578  ORD0020579 2023-09-24  CUST016754  Sneha Sharma    P00015
# 95429  ORD0095430 2023-03-08  CUST001586  Sunita Joshi    P00006
# 51547  ORD0051548 2024-03-22  CUST024376  Vihaan Gupta    P00013
#
#              ProductName           Category       Brand  Quantity  UnitPrice  \
# 48442      Puzzle 1000pc     Home & Kitchen  URBANSTYLE         5     598.29
# 81886   Wireless Charger       Toys & Games    HOMEEASE         5     596.47
# ...

# %%
plt.boxplot(df["TotalAmount"])
plt.title("TotalAmount Box Plot")
plt.ylabel("TotalAmount")
plt.show()

# %%
q1 = df["TotalAmount"].quantile(0.25)
q3 = df["TotalAmount"].quantile(0.75)
IQR = q3 - q1
print(q1, q3, IQR)
# Out:
# 340.89 1349.7649999999999 1008.8749999999999

# %%
lower_limit = q1 - 1.5 * IQR
upper_limit = q3 + 1.5 *IQR
print(lower_limit)
print(upper_limit)
# Out:
# -1172.4224999999997
# 2863.0774999999994

# %%
outliers = df[(df["TotalAmount"] < lower_limit) | (df["TotalAmount"] > upper_limit)]
outliers.head(10)
# Out:
#           OrderID  OrderDate  CustomerID  CustomerName ProductID  \
# 48442  ORD0048443 2020-01-12  CUST010794  Anjali Patel    P00033
# 81886  ORD0081887 2020-09-26  CUST031626  Vivaan Joshi    P00048
# 4196   ORD0004197 2021-02-22  CUST022868   Kabir Gupta    P00029
# 1929   ORD0001930 2023-08-18  CUST031209   Pooja Patel    P00025
# 58204  ORD0058205 2021-10-19  CUST033287   Priya Gupta    P00031
# 46764  ORD0046765 2024-04-13  CUST044400  Priya Kapoor    P00034
# 40146  ORD0040147 2024-10-07  CUST001991   Pooja Mehta    P00002
# 20578  ORD0020579 2023-09-24  CUST016754  Sneha Sharma    P00015
# 95429  ORD0095430 2023-03-08  CUST001586  Sunita Joshi    P00006
# 51547  ORD0051548 2024-03-22  CUST024376  Vihaan Gupta    P00013
#
#              ProductName           Category       Brand  Quantity  UnitPrice  \
# 48442      Puzzle 1000pc     Home & Kitchen  URBANSTYLE         5     598.29
# 81886   Wireless Charger       Toys & Games    HOMEEASE         5     596.47
# ...

# %%
len(outliers)
# Out:
# 1360

# %%
df.shape
# Out:
# (100000, 27)

# %%
df.isnull().sum()
# Out:
# OrderID            0
# OrderDate          0
# CustomerID         0
# CustomerName       0
# ProductID          0
# ProductName        0
# Category           0
# Brand              0
# Quantity           0
# UnitPrice          0
# Discount           0
# Tax                0
# ShippingCost       0
# TotalAmount        0
# PaymentMethod      0
# OrderStatus        0
# City               0
# State              0
# Country            0
# SellerID           0
# OrderMonth         0
# OrderYear          0
# MonthName          0
# DayName            0
# Quarter            0
# PriceCategory      0
# DiscountPercent    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# OrderID                       str
# OrderDate          datetime64[us]
# CustomerID                    str
# CustomerName                  str
# ProductID                     str
# ProductName                   str
# Category                      str
# Brand                         str
# Quantity                    int64
# UnitPrice                 float64
# Discount                  float64
# Tax                       float64
# ShippingCost              float64
# TotalAmount               float64
# PaymentMethod                 str
# OrderStatus                   str
# City                          str
# State                         str
# Country                       str
# SellerID                      str
# OrderMonth                  int32
# OrderYear                   int32
# MonthName                     str
# DayName                       str
# Quarter                     int32
# PriceCategory            category
# DiscountPercent           float64
# dtype: object

# %%
df.head()
# Out:
#           OrderID  OrderDate  CustomerID  CustomerName ProductID  \
# 48442  ORD0048443 2020-01-12  CUST010794  Anjali Patel    P00033
# 81886  ORD0081887 2020-09-26  CUST031626  Vivaan Joshi    P00048
# 4196   ORD0004197 2021-02-22  CUST022868   Kabir Gupta    P00029
# 1929   ORD0001930 2023-08-18  CUST031209   Pooja Patel    P00025
# 58204  ORD0058205 2021-10-19  CUST033287   Priya Gupta    P00031
#
#             ProductName        Category       Brand  Quantity  UnitPrice  ...  \
# 48442     Puzzle 1000pc  Home & Kitchen  URBANSTYLE         5     598.29  ...
# 81886  Wireless Charger    Toys & Games    HOMEEASE         5     596.47  ...
# 4196            T-Shirt  Home & Kitchen      ZENITH         5     595.26  ...
# 1929      Running Shoes           Books    KIDDOFUN         5     594.85  ...
# 58204      Kids Toy Car  Home & Kitchen     FITLIFE         5     594.46  ...
#
#        State         Country   SellerID  OrderMonth OrderYear  MonthName  \
# ...

# %%
df.to_csv("Amazon_Sales_cleaned1.csv", index=False)

# %%
total_sales = df["TotalAmount"].sum()
print("Total_Sales:", total_sales)
# Out:
# Total_Sales: 91825647.91999999

# %%
total_orders = df["OrderID"].count()
print("Total_Orders:", total_orders)
# Out:
# Total_Orders: 100000

# %%
total_customers = df["CustomerID"].nunique()
print("Total_Customers:", total_customers)
# Out:
# Total_Customers: 43233

# %%
average_order = df["TotalAmount"].mean()
print("Averag_Order:", average_order)
# Out:
# Averag_Order: 918.2564791999998

# %%
max_order = df["TotalAmount"].max()
print("Highest Order Value:", max_order)
# Out:
# Highest Order Value: 3534.98

# %%
min_order = df["TotalAmount"].min()
print("Lowest Order Value:", min_order)
# Out:
# Lowest Order Value: 4.27

# %%
print("========== AMAZON SALES OVERVIEW ==========")
print("Total Sales:", df["TotalAmount"].sum())
print("Total Orders:", df["OrderID"].count())
print("Unique Customers:", df["CustomerID"].nunique())
print("Average Order Value:", df["TotalAmount"].mean())
print("Highest Order Value:", df["TotalAmount"].max())
print("Lowest Order Value:", df["TotalAmount"].min())
# Out:
# ========== AMAZON SALES OVERVIEW ==========
# Total Sales: 91825647.91999999
# Total Orders: 100000
# Unique Customers: 43233
# Average Order Value: 918.2564791999998
# Highest Order Value: 3534.98
# Lowest Order Value: 4.27

# %%
category_sales = df.groupby("Category")["TotalAmount"].sum()
category_sales
# Out:
# Category
# Books                15261837.01
# Clothing             15253397.50
# Electronics          15584217.18
# Home & Kitchen       15163939.36
# Sports & Outdoors    15345571.88
# Toys & Games         15216684.99
# Name: TotalAmount, dtype: float64

# %%
category_sales = category_sales.sort_values(ascending=False)
category_sales
# Out:
# Category
# Electronics          15584217.18
# Sports & Outdoors    15345571.88
# Books                15261837.01
# Clothing             15253397.50
# Toys & Games         15216684.99
# Home & Kitchen       15163939.36
# Name: TotalAmount, dtype: float64

# %%
category_sales.plot(kind="bar")
plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.savefig("Total Sales by Category.png")
plt.show()

# %%
product_sales = df.groupby("ProductName")["TotalAmount"].sum()
product_sales
# Out:
# ProductName
# 4K Monitor                     1866774.35
# Action Camera                  1829029.24
# Air Fryer                      1789927.34
# Backpack                       1749971.14
# Bluetooth Speaker              1803356.76
# Board Game                     1863310.96
# Car Charger                    1779795.27
# Children's Book                1738112.57
# Cookware Set                   1877038.73
# Desk Organizer                 1843103.26
# Desk Plant                     1759672.62
# Dress Shirt                    1896765.36
# Drone Mini                     1816203.39
# Electric Kettle                1905751.79
# External HDD 2TB               1786108.33
# Fitness Band                   1784149.50
# Gaming Mouse                   1895103.98
# Graphic Tablet                 1786772.26
# HDMI Cable 2m                  1847856.25
# Instant Pot                    1838639.12
# Jeans                          1882591.82
# Kids Toy Car                   1891082.43
# ...

# %%
product_sales = product_sales.sort_values(ascending=False)
product_sales
# Out:
# ProductName
# Memory Card 128GB              1935138.40
# LED Desk Lamp                  1921948.41
# Mechanical Keyboard            1906963.54
# Electric Kettle                1905751.79
# Smartwatch                     1901275.59
# Dress Shirt                    1896765.36
# Water Bottle                   1895467.95
# Gaming Mouse                   1895103.98
# Kids Toy Car                   1891082.43
# Jeans                          1882591.82
# Noise Cancelling Headphones    1881108.57
# Cookware Set                   1877038.73
# Smartphone Case                1875421.41
# Microphone                     1871740.68
# Smart Light Bulb               1868940.58
# 4K Monitor                     1866774.35
# Phone Tripod                   1866256.31
# Board Game                     1863310.96
# Vacuum Cleaner                 1855117.83
# Router                         1850756.20
# Laptop Sleeve                  1848297.80
# Yoga Mat                       1847898.09
# ...

# %%
top10_products = product_sales.head(10)
top10_products
# Out:
# ProductName
# Memory Card 128GB      1935138.40
# LED Desk Lamp          1921948.41
# Mechanical Keyboard    1906963.54
# Electric Kettle        1905751.79
# Smartwatch             1901275.59
# Dress Shirt            1896765.36
# Water Bottle           1895467.95
# Gaming Mouse           1895103.98
# Kids Toy Car           1891082.43
# Jeans                  1882591.82
# Name: TotalAmount, dtype: float64

# %%
top10_products.plot(kind = "bar")
plt.title("top10 Products")
plt.xlabel("ProductName")
plt.ylabel("top10_products")
plt.xticks(rotation=45)
plt.savefig("Top12 Products.png")
plt.show()

# %%
monthly_sales = df.groupby("MonthName")["TotalAmount"].sum()
monthly_sales
# Out:
# MonthName
# April        7646203.22
# August       7890598.37
# December     7740979.01
# February     6931724.49
# January      7883801.27
# July         7737925.51
# June         7654636.75
# March        7766527.73
# May          7864283.27
# November     7495754.13
# October      7654243.32
# September    7558970.85
# Name: TotalAmount, dtype: float64

# %%
month_order =["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
monthly_sales = monthly_sales.reindex(month_order)
monthly_sales
# Out:
# MonthName
# January      7883801.27
# February     6931724.49
# March        7766527.73
# April        7646203.22
# May          7864283.27
# June         7654636.75
# July         7737925.51
# August       7890598.37
# September    7558970.85
# October      7654243.32
# November     7495754.13
# December     7740979.01
# Name: TotalAmount, dtype: float64

# %%
monthly_sales.plot(kind="line", marker="o", linewidth=2)
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.savefig("Monthly Sales Trend.png")
plt.show()

# %%
country_sales = df.groupby("Country")["TotalAmount"].sum()
country_sales = country_sales.sort_values(ascending=False)
country_sales
# Out:
# Country
# United States     64310048.50
# India             13875839.12
# Canada             5323757.00
# United Kingdom     4526896.86
# Australia          3789106.44
# Name: TotalAmount, dtype: float64

# %%
country_sales.plot(kind = "bar")
plt.title("Country Sales")
plt.xlabel("Country")
plt.ylabel("Total Sales")
plt.savefig("Country Sales.png")
plt.show()

# %%
state_sales = df.groupby("State")["TotalAmount"].sum()
state_sales = state_sales.sort_values(ascending=False)
state_sales
# Out:
# State
# TX    22862540.54
# CA    18231196.79
# NC     4747701.73
# WA     4660962.17
# PA     4650673.88
# CO     4638498.97
# IL     4632847.44
# OH     4615442.32
# IN     4609048.43
# FL     4597177.27
# NY     4554358.08
# DC     4520876.11
# AZ     4504324.19
# Name: TotalAmount, dtype: float64

# %%
top10_states = state_sales.head(10)
top10_states
# Out:
# State
# TX    22862540.54
# CA    18231196.79
# NC     4747701.73
# WA     4660962.17
# PA     4650673.88
# CO     4638498.97
# IL     4632847.44
# OH     4615442.32
# IN     4609048.43
# FL     4597177.27
# Name: TotalAmount, dtype: float64

# %%
top10_states.plot(kind = "bar")
plt.title("Top10 States by Sales")
plt.xlabel("State")
plt.ylabel("Total Sales")
plt.savefig("Top10 State Sales.png")
plt.show()

# %%
print(country_sales.idxmax())
# Out:
# United States

# %%
print(state_sales.idxmax())
# Out:
# TX

# %%
print(country_sales.max())
print(state_sales.max())
# Out:
# 64310048.5
# 22862540.54

# %%
payment_count = df["PaymentMethod"].value_counts()
payment_count
# Out:
# PaymentMethod
# Credit Card         35038
# Debit Card          20024
# UPI                 15066
# Amazon Pay          15017
# Net Banking          9927
# Cash on Delivery     4928
# Name: count, dtype: int64

# %%
payment_count.plot(kind="bar")
plt.title("Orders by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("No.of Orders")
plt.xticks(rotation=45)
plt.savefig("Payment Method.png")
plt.show()

# %%
payment_count.plot(kind = "pie", autopct = "%1.1f%%")
plt.ylabel("")
plt.title("Payment Method Distribution")
plt.savefig("Payment Method Distribution.png")
plt.show()

# %%
payment_sales = df.groupby("PaymentMethod")["TotalAmount"].sum()
payment_sales = payment_sales.sort_values(ascending=False)
payment_sales
# Out:
# PaymentMethod
# Credit Card         32122158.69
# Debit Card          18538678.53
# UPI                 13896028.55
# Amazon Pay          13697498.42
# Net Banking          9055674.57
# Cash on Delivery     4515609.16
# Name: TotalAmount, dtype: float64

# %%
payment_sales.plot(kind="bar")
plt.title("Sales by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.savefig("Payment Method Sales.png")
plt.show()

# %%
print(payment_count.idxmax())
# Out:
# Credit Card

# %%
print(payment_sales.idxmax())
# Out:
# Credit Card

# %%
order_status = df["OrderStatus"].value_counts()
order_status
# Out:
# OrderStatus
# Delivered    74628
# Shipped      15192
# Pending       4103
# Returned      3049
# Cancelled     3028
# Name: count, dtype: int64

# %%
order_status.plot(kind="bar")
plt.title("Order Status Distribution")
plt.xlabel("Order Status")
plt.ylabel("No.of Orders")
plt.xticks(rotation=45)
plt.savefig("Payment Method.png")
plt.show()

# %%
order_status.plot(kind = "pie", autopct = "%1.1f%%")
plt.ylabel("")
plt.title("Order Status Distribution")
plt.savefig("Order Status Pie_Distribution.png")
plt.show()

# %%
print(order_status.idxmax())
# Out:
# Delivered

# %%
print(order_status.idxmin())
# Out:
# Cancelled

# %%
print(order_status.max())
# Out:
# 74628

# %%
print(order_status.min())
# Out:
# 3028

# %%
average_discount = df["DiscountPercent"].mean()
print("Aerage Discount:", average_discount)
# Out:
# Aerage Discount: 7.4226

# %%
max_discount = df["DiscountPercent"].max()
print("Maximum Discount:", max_discount)
# Out:
# Maximum Discount: 30.0

# %%
min_discount = df["DiscountPercent"].min()
print("Minimum Discount:", min_discount)
# Out:
# Minimum Discount: 0.0

# %%
plt.hist(df["DiscountPercent"], bins=20)
plt.title("Distribution of Discount Percentage")
plt.xlabel("Discount")
plt.ylabel("No.of Products")
plt.show()

# %%
plt.boxplot(df["DiscountPercent"])
plt.title("Box Plot of Discount Percentage")
plt.ylabel("Discount")
plt.show()

# %%
plt.scatter(df["DiscountPercent"], df["TotalAmount"])
plt.title(" Discount vs Total Sales")
plt.xlabel("Discount")
plt.ylabel("Total Amount")
plt.show()

# %%
average_shipping = df["ShippingCost"].mean()
print("Average Shipping Cost:", average_shipping)
# Out:
# Average Shipping Cost: 7.4066601

# %%
max_shipping = df["ShippingCost"].max()
print("Maximum Shipping Cost:", max_shipping)
# Out:
# Maximum Shipping Cost: 15.0

# %%
min_shipping = df["ShippingCost"].min()
print("Minimum Shipping Cost:", min_shipping)
# Out:
# Minimum Shipping Cost: 0.0

# %%
plt.hist(df["ShippingCost"], bins=10)
plt.title("Shipping Cost Distribution")
plt.xlabel("Shipping Cost")
plt.ylabel("No.of Orders")
plt.show()

# %%
plt.boxplot(df["ShippingCost"])
plt.title("Box Plot of Shipping Cost")
plt.ylabel("Shipping Cost")
plt.show()

# %%
plt.scatter(df["ShippingCost"], df["TotalAmount"])
plt.title(" Shipping Cost vs Total Sales")
plt.xlabel("Shipping Cost")
plt.ylabel("Total Amount")
plt.show()

# %%
numerical_df = df.select_dtypes(include=["int64","float64"])
numerical_df
# Out:
#        Quantity  UnitPrice  Discount     Tax  ShippingCost  TotalAmount  \
# 48442         5     598.29      0.00  538.46          5.07      3534.98
# 81886         5     596.47      0.00  536.82          2.68      3521.85
# 4196          5     595.26      0.00  535.73          2.21      3514.24
# 1929          5     594.85      0.00  535.36          4.04      3513.65
# 58204         5     594.46      0.00  535.01          5.74      3513.05
# ...         ...        ...       ...     ...           ...          ...
# 38172         1       5.89      0.00    0.47          0.05         6.41
# 4730          1       6.25      0.20    0.00          1.19         6.19
# 99805         1       6.08      0.05    0.29          0.12         6.19
# 68176         1       5.26      0.20    0.76          0.62         5.59
# 86771         1       5.57      0.30    0.31          0.06         4.27
#
#        DiscountPercent
# 48442              0.0
# 81886              0.0
# 4196               0.0
# ...

# %%
correlation = numerical_df.corr()
correlation
# Out:
#                  Quantity  UnitPrice  Discount       Tax  ShippingCost  \
# Quantity         1.000000   0.004408 -0.000398  0.437884      0.020047
# UnitPrice        0.004408   1.000000  0.006159  0.526856      0.045773
# Discount        -0.000398   0.006159  1.000000 -0.077550      0.000315
# Tax              0.437884   0.526856 -0.077550  1.000000      0.023498
# ShippingCost     0.020047   0.045773  0.000315  0.023498      1.000000
# TotalAmount      0.594928   0.715808 -0.108088  0.779399      0.039349
# DiscountPercent -0.000398   0.006159  1.000000 -0.077550      0.000315
#
#                  TotalAmount  DiscountPercent
# Quantity            0.594928        -0.000398
# UnitPrice           0.715808         0.006159
# Discount           -0.108088         1.000000
# Tax                 0.779399        -0.077550
# ShippingCost        0.039349         0.000315
# TotalAmount         1.000000        -0.108088
# DiscountPercent    -0.108088         1.000000

# %%
sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.savefig("corr_heatmap.png")
plt.show()
